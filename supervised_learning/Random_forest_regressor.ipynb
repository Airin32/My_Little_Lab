# %%
import pandas as pd
import seaborn as sns 
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
healthexp = sns.load_dataset('healthexp')

# %%
healthexp
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 0    1970        Germany       252.311             70.6
# 1    1970         France       192.143             72.2
# 2    1970  Great Britain       123.993             71.9
# 3    1970          Japan       150.437             72.0
# 4    1970            USA       326.961             70.9
# ..    ...            ...           ...              ...
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0
#
# [274 rows x 4 columns]

# %%
df = pd.get_dummies(healthexp)

# %%
x = df.drop(['Life_Expectancy'],axis=1)
y =df['Life_Expectancy']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=4)

# %%
rfr = RandomForestRegressor(random_state=13)

# %%
rfr.fit(x_train,y_train)
# Out:
# RandomForestRegressor(random_state=13)

# %%
y_pred = rfr.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score

# %%
mean_absolute_error(y_pred,y_test)
# Out:
# 0.2833818181818298

# %%
y_pred
# Out:
# array([81.887, 83.95 , 80.267, 74.944, 74.837, 81.879, 80.993, 76.173,
#        73.509, 80.947, 78.676, 71.291, 72.401, 80.202, 81.549, 71.835,
#        82.631, 78.595, 74.912, 81.287, 79.08 , 71.866, 73.501, 76.81 ,
#        76.933, 75.455, 77.602, 84.07 , 79.758, 72.922, 81.262, 74.464,
#        77.678, 75.805, 83.649, 73.859, 84.379, 76.099, 77.623, 82.684,
#        78.234, 82.063, 77.416, 82.702, 75.327, 76.137, 77.573, 81.262,
#        76.436, 78.599, 82.026, 79.244, 78.676, 76.043, 76.382])
