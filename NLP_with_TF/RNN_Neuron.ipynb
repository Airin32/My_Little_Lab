# %%
import tensorflow as tf 
from tensorflow.keras.preprocessing.text import Tokenizer 
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
import numpy as np

# %%
data = [
    "saya suka belajar AI",
    "belajar AI adalah hal yang menyenangkan",
    "saya ingin menjadi seorang AI engineer",
    "AI memiliki banyak aplikasi",
    "AI dapat membantu memecahkan masalah kompleks",
    "belajar AI bisa mengasah logika"
]

# %%
tokenizer = Tokenizer(num_words=1000,oov_token="<OOV>")

# %%
tokenizer.fit_on_texts(data)

# %%
vocab_size = len(tokenizer.word_index) + 1

# %%
sequences = tokenizer.texts_to_sequences(data)

# %%
padding = pad_sequences(sequences,maxlen=20,padding='post',truncating='post')

# %%
X,y = padding[:,:-1],padding[:,-1]

# %%
y = tf.keras.utils.to_categorical(y,num_classes=vocab_size)

# %%
model2 = tf.keras.Sequential()

# %%
model2.add(tf.keras.layers.Embedding(input_dim=vocab_size,output_dim=64,input_length = X.shape[1]))
model2.add(tf.keras.layers.SimpleRNN(128))
model2.add(tf.keras.layers.Dense(vocab_size,activation='softmax'))
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model2.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model2.fit(X,y,verbose=2,epochs=100)
# Out:
# Epoch 1/100
# 1/1 - 0s - 64ms/step - accuracy: 1.0000 - loss: 5.4841e-04
# Epoch 2/100
# 1/1 - 0s - 194ms/step - accuracy: 1.0000 - loss: 5.4494e-04
# Epoch 3/100
# 1/1 - 0s - 72ms/step - accuracy: 1.0000 - loss: 5.4154e-04
# Epoch 4/100
# 1/1 - 0s - 62ms/step - accuracy: 1.0000 - loss: 5.3803e-04
# Epoch 5/100
# 1/1 - 0s - 46ms/step - accuracy: 1.0000 - loss: 5.3459e-04
# Epoch 6/100
# 1/1 - 0s - 67ms/step - accuracy: 1.0000 - loss: 5.3125e-04
# Epoch 7/100
# 1/1 - 0s - 54ms/step - accuracy: 1.0000 - loss: 5.2786e-04
# Epoch 8/100
# 1/1 - 0s - 56ms/step - accuracy: 1.0000 - loss: 5.2456e-04
# Epoch 9/100
# 1/1 - 0s - 57ms/step - accuracy: 1.0000 - loss: 5.2125e-04
# Epoch 10/100
# 1/1 - 0s - 69ms/step - accuracy: 1.0000 - loss: 5.1799e-04
# Epoch 11/100
# 1/1 - 0s - 51ms/step - accuracy: 1.0000 - loss: 5.1473e-04
# Epoch 12/100
# 1/1 - 0s - 48ms/step - accuracy: 1.0000 - loss: 5.1161e-04
# Epoch 13/100
# 1/1 - 0s - 64ms/step - accuracy: 1.0000 - loss: 5.0838e-04
# Epoch 14/100
# ...

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense

# 1. Data Preparation
data = [
    "saya suka belajar AI",
    "belajar AI adalah hal yang menyenangkan",
    "saya ingin menjadi seorang AI engineer",
    "AI memiliki banyak aplikasi",
    "AI dapat membantu memecahkan masalah kompleks",
    "belajar AI bisa mengasah logika"
]

# Tokenize the text data
tokenizer = Tokenizer()
tokenizer.fit_on_texts(data)
total_words = len(tokenizer.word_index) + 1

# Convert the sentences into sequences of integers
input_sequences = []
for line in data:
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i+1]
        input_sequences.append(n_gram_sequence)

# Pad sequences to have the same length
max_sequence_len = max([len(x) for x in input_sequences])
input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre'))

# Split data into inputs and labels
X, y = input_sequences[:,:-1], input_sequences[:,-1]
y = tf.keras.utils.to_categorical(y, num_classes=total_words)

# 2. Build RNN Model
model = Sequential([
    Embedding(total_words, 64, input_length=max_sequence_len-1),
    SimpleRNN(128),
    Dense(total_words, activation='softmax')
])

# 3. Compile the Model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# 4. Train the Model
model.fit(X, y, epochs=100, verbose=1)

# 5. Function to Predict Next Word
def predict_next_word(seed_text, next_words):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
        predicted = np.argmax(model.predict(token_list), axis=-1)
        
        output_word = ""
        for word, index in tokenizer.word_index.items():
            if index == predicted:
                output_word = word
                break
        seed_text += " " + output_word
    return seed_text

# Test the model
print(predict_next_word("saya suka", 3))
# Out:
# Epoch 1/100
# c:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step - accuracy: 0.0000e+00 - loss: 3.1982
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.0400 - loss: 3.1540
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.2000 - loss: 3.1105
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.2800 - loss: 3.0664
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.2800 - loss: 3.0209
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.2800 - loss: 2.9731
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.2800 - loss: 2.9223
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.2800 - loss: 2.8684
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.2800 - loss: 2.8121
# ...

# %%
def predict_word(seed_text, next_words):
    for _ in range(next_words):
        # Mengonversi teks menjadi token
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=20, padding='post', truncating='post')
        
        # Memprediksi kata berikutnya
        predicted = np.argmax(model2.predict(token_list), axis=-1)
        
        # Mengambil kata dari `index_word` menggunakan indeks prediksi
        output_word = tokenizer.index_word.get(predicted[0], "")
        
        # Menambahkan kata ke teks awal jika kata ditemukan
        if output_word:
            seed_text += " " + output_word
        else:
            break  # Jika tidak ada prediksi yang relevan, hentikan proses

    return seed_text

# %%
data
# Out:
# ['saya suka belajar AI',
#  'belajar AI adalah hal yang menyenangkan',
#  'saya ingin menjadi seorang AI engineer',
#  'AI memiliki banyak aplikasi',
#  'AI dapat membantu memecahkan masalah kompleks',
#  'belajar AI bisa mengasah logika']

# %%
predict_next_word("saya suka",3)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 'saya suka yang yang yang'

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

data = [
    "saya suka belajar AI",
    "belajar AI adalah hal yang menyenangkan",
    "saya ingin menjadi seorang AI engineer",
    "AI memiliki banyak aplikasi",
    "AI dapat membantu memecahkan masalah kompleks",
    "belajar AI bisa mengasah logika"
]

# Tokenization and Padding
tokenizer = Tokenizer(num_words=1000, oov_token="<OOV>")
tokenizer.fit_on_texts(data)
vocab_size = len(tokenizer.word_index) + 1

sequences = tokenizer.texts_to_sequences(data)
padding = pad_sequences(sequences, maxlen=20, padding='post', truncating='post')

# Preparing input and labels
X, y = padding[:, :-1], padding[:, -1]
y = tf.keras.utils.to_categorical(y, num_classes=vocab_size)

# Model Definition
model2 = tf.keras.Sequential()
model2.add(tf.keras.layers.Embedding(input_dim=vocab_size, output_dim=64, input_length=X.shape[1]))
model2.add(tf.keras.layers.SimpleRNN(128))
model2.add(tf.keras.layers.Dense(vocab_size, activation='softmax'))

# Compiling the Model
model2.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Training the Model
model2.fit(X, y, epochs=100)
# Out:
# Epoch 1/100
# c:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.0000e+00 - loss: 3.3225
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8333 - loss: 2.7780
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 2.2801
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.7543
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 1.2563
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 1.0000 - loss: 0.8671
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 1.0000 - loss: 0.5894
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.3892
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 1.0000 - loss: 0.2478
# ...
